# %%
print("Name: Lokesh Dhoble")
print("Roll no.: TACO22131")
# Out:
# Name: Lokesh Dhoble
# Roll no.: TACO22131

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv(r"C:\Users\Loki\Desktop\lp 2\end term\Extended_Employee_Performance_and_Productivity_Data.csv")
df
# Out:
#        Employee_ID        Department  Gender  Age   Job_Title  \
# 0                1                IT    Male   55  Specialist
# 1                2           Finance    Male   29   Developer
# 2                3           Finance    Male   55  Specialist
# 3                4  Customer Support  Female   48     Analyst
# 4                5       Engineering  Female   36     Analyst
# ...            ...               ...     ...  ...         ...
# 99995        99996           Finance    Male   27  Technician
# 99996        99997                IT  Female   36  Consultant
# 99997        99998        Operations    Male   53     Analyst
# 99998        99999                HR  Female   22  Consultant
# 99999       100000           Finance  Female   43     Analyst
#
#                         Hire_Date  Years_At_Company Education_Level  \
# 0      2022-01-19 08:03:05.556036                 2     High School
# 1      2024-04-18 08:03:05.556036                 0     High School
# 2      2015-10-26 08:03:05.556036                 8     High School
# 3      2016-10-22 08:03:05.556036                 7        Bachelor
# 4      2021-07-23 08:03:05.556036                 3        Bachelor
# ...                           ...               ...             ...
# 99995  2022-12-07 08:03:05.556036                 1        Bachelor
# 99996  2018-07-24 08:03:05.556036                 6          Master
# 99997  2015-11-24 08:03:05.556036                 8     High School
# 99998  2015-08-03 08:03:05.556036                 9     High School
# 99999  2024-03-04 08:03:05.556036                 0             PhD
#
#        Performance_Score  Monthly_Salary  Work_Hours_Per_Week  \
# 0                      5          6750.0                   33
# 1                      5          7500.0                   34
# 2                      3          5850.0                   37
# 3                      2          4800.0                   52
# 4                      2          4800.0                   38
# ...                  ...             ...                  ...
# 99995                  4          4900.0                   55
# 99996                  5          8250.0                   39
# 99997                  2          4800.0                   31
# 99998                  5          8250.0                   35
# 99999                  1          4400.0                   51
#
#        Projects_Handled  Overtime_Hours  Sick_Days  Remote_Work_Frequency  \
# 0                    32              22          2                      0
# 1                    34              13         14                    100
# 2                    27               6          3                     50
# 3                    10              28         12                    100
# 4                    11              29         13                    100
# ...                 ...             ...        ...                    ...
# 99995                46               5          3                     75
# 99996                35               7          0                      0
# 99997                13               6          5                      0
# 99998                43              10          1                     75
# 99999                43              27         11                     75
#
#        Team_Size  Training_Hours  Promotions  Employee_Satisfaction_Score  \
# 0             14              66           0                         2.63
# 1             12              61           2                         1.72
# 2             10               1           0                         3.17
# 3             10               0           1                         1.86
# 4             15               9           1                         1.25
# ...          ...             ...         ...                          ...
# 99995         16              48           2                         1.28
# 99996         10              77           1                         3.48
# 99997          5              87           1                         2.60
# 99998          2              31           1                         3.10
# 99999         13              45           1                         2.64
#
#        Resigned
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 99995     False
# 99996      True
# 99997     False
# 99998     False
# 99999     False
#
# [100000 rows x 20 columns]

# %%
df.drop(["Department", "Gender", 
"Job_Title","Hire_Date","Resigned"],axis=1, inplace=True)
df
# Out:
#        Employee_ID  Age  Years_At_Company Education_Level  Performance_Score  \
# 0                1   55                 2     High School                  5
# 1                2   29                 0     High School                  5
# 2                3   55                 8     High School                  3
# 3                4   48                 7        Bachelor                  2
# 4                5   36                 3        Bachelor                  2
# ...            ...  ...               ...             ...                ...
# 99995        99996   27                 1        Bachelor                  4
# 99996        99997   36                 6          Master                  5
# 99997        99998   53                 8     High School                  2
# 99998        99999   22                 9     High School                  5
# 99999       100000   43                 0             PhD                  1
#
#        Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  \
# 0              6750.0                   33                32              22
# 1              7500.0                   34                34              13
# 2              5850.0                   37                27               6
# 3              4800.0                   52                10              28
# 4              4800.0                   38                11              29
# ...               ...                  ...               ...             ...
# 99995          4900.0                   55                46               5
# 99996          8250.0                   39                35               7
# 99997          4800.0                   31                13               6
# 99998          8250.0                   35                43              10
# 99999          4400.0                   51                43              27
#
#        Sick_Days  Remote_Work_Frequency  Team_Size  Training_Hours  \
# 0              2                      0         14              66
# 1             14                    100         12              61
# 2              3                     50         10               1
# 3             12                    100         10               0
# 4             13                    100         15               9
# ...          ...                    ...        ...             ...
# 99995          3                     75         16              48
# 99996          0                      0         10              77
# 99997          5                      0          5              87
# 99998          1                     75          2              31
# 99999         11                     75         13              45
#
#        Promotions  Employee_Satisfaction_Score
# 0               0                         2.63
# 1               2                         1.72
# 2               0                         3.17
# 3               1                         1.86
# 4               1                         1.25
# ...           ...                          ...
# 99995           2                         1.28
# 99996           1                         3.48
# 99997           1                         2.60
# 99998           1                         3.10
# 99999           1                         2.64
#
# [100000 rows x 15 columns]

# %%
df["Education_Level"].unique()
# Out:
# array(['High School', 'Bachelor', 'Master', 'PhD'], dtype=object)

# %%
le = LabelEncoder()
df['Education_Level'] = le.fit_transform(df['Education_Level'])
df
# Out:
#        Employee_ID  Age  Years_At_Company  Education_Level  Performance_Score  \
# 0                1   55                 2                1                  5
# 1                2   29                 0                1                  5
# 2                3   55                 8                1                  3
# 3                4   48                 7                0                  2
# 4                5   36                 3                0                  2
# ...            ...  ...               ...              ...                ...
# 99995        99996   27                 1                0                  4
# 99996        99997   36                 6                2                  5
# 99997        99998   53                 8                1                  2
# 99998        99999   22                 9                1                  5
# 99999       100000   43                 0                3                  1
#
#        Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  \
# 0              6750.0                   33                32              22
# 1              7500.0                   34                34              13
# 2              5850.0                   37                27               6
# 3              4800.0                   52                10              28
# 4              4800.0                   38                11              29
# ...               ...                  ...               ...             ...
# 99995          4900.0                   55                46               5
# 99996          8250.0                   39                35               7
# 99997          4800.0                   31                13               6
# 99998          8250.0                   35                43              10
# 99999          4400.0                   51                43              27
#
#        Sick_Days  Remote_Work_Frequency  Team_Size  Training_Hours  \
# 0              2                      0         14              66
# 1             14                    100         12              61
# 2              3                     50         10               1
# 3             12                    100         10               0
# 4             13                    100         15               9
# ...          ...                    ...        ...             ...
# 99995          3                     75         16              48
# 99996          0                      0         10              77
# 99997          5                      0          5              87
# 99998          1                     75          2              31
# 99999         11                     75         13              45
#
#        Promotions  Employee_Satisfaction_Score
# 0               0                         2.63
# 1               2                         1.72
# 2               0                         3.17
# 3               1                         1.86
# 4               1                         1.25
# ...           ...                          ...
# 99995           2                         1.28
# 99996           1                         3.48
# 99997           1                         2.60
# 99998           1                         3.10
# 99999           1                         2.64
#
# [100000 rows x 15 columns]

# %%
df['High_Performer'] = (df['Performance_Score'] >= 4).astype(int)
df
# Out:
#        Employee_ID  Age  Years_At_Company  Education_Level  Performance_Score  \
# 0                1   55                 2                1                  5
# 1                2   29                 0                1                  5
# 2                3   55                 8                1                  3
# 3                4   48                 7                0                  2
# 4                5   36                 3                0                  2
# ...            ...  ...               ...              ...                ...
# 99995        99996   27                 1                0                  4
# 99996        99997   36                 6                2                  5
# 99997        99998   53                 8                1                  2
# 99998        99999   22                 9                1                  5
# 99999       100000   43                 0                3                  1
#
#        Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  \
# 0              6750.0                   33                32              22
# 1              7500.0                   34                34              13
# 2              5850.0                   37                27               6
# 3              4800.0                   52                10              28
# 4              4800.0                   38                11              29
# ...               ...                  ...               ...             ...
# 99995          4900.0                   55                46               5
# 99996          8250.0                   39                35               7
# 99997          4800.0                   31                13               6
# 99998          8250.0                   35                43              10
# 99999          4400.0                   51                43              27
#
#        Sick_Days  Remote_Work_Frequency  Team_Size  Training_Hours  \
# 0              2                      0         14              66
# 1             14                    100         12              61
# 2              3                     50         10               1
# 3             12                    100         10               0
# 4             13                    100         15               9
# ...          ...                    ...        ...             ...
# 99995          3                     75         16              48
# 99996          0                      0         10              77
# 99997          5                      0          5              87
# 99998          1                     75          2              31
# 99999         11                     75         13              45
#
#        Promotions  Employee_Satisfaction_Score  High_Performer
# 0               0                         2.63               1
# 1               2                         1.72               1
# 2               0                         3.17               0
# 3               1                         1.86               0
# 4               1                         1.25               0
# ...           ...                          ...             ...
# 99995           2                         1.28               1
# 99996           1                         3.48               1
# 99997           1                         2.60               0
# 99998           1                         3.10               1
# 99999           1                         2.64               0
#
# [100000 rows x 16 columns]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='High_Performer', y='Monthly_Salary', data=df, 
palette='Set2')
plt.title("Monthly Salary vs. High Performers")
plt.xlabel("High Performer (1 = Yes, 0 = No)")
plt.ylabel("Monthly Salary")
plt.show()
# Out:
# C:\Users\Loki\AppData\Local\Temp\ipykernel_36472\3091665500.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='High_Performer', y='Monthly_Salary', data=df,

# %%
X = df[['Performance_Score', 'Education_Level', 
'Employee_Satisfaction_Score', 'Promotions']]
Y = df['High_Performer']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, 
test_size=0.2, random_state=42)
X_test
# Out:
#        Performance_Score  Education_Level  Employee_Satisfaction_Score  \
# 75721                  2                2                         4.59
# 80184                  4                1                         4.83
# 19864                  3                1                         2.23
# 76699                  1                2                         4.88
# 92991                  4                0                         3.68
# ...                  ...              ...                          ...
# 32595                  3                1                         1.57
# 29313                  4                2                         3.88
# 37862                  2                2                         1.49
# 53421                  5                0                         1.92
# 42410                  3                0                         2.41
#
#        Promotions
# 75721           0
# 80184           1
# 19864           0
# 76699           0
# 92991           1
# ...           ...
# 32595           2
# 29313           0
# 37862           0
# 53421           2
# 42410           0
#
# [20000 rows x 4 columns]

# %%
lr = LogisticRegression()
lr.fit(X_train, Y_train)
LogisticRegression()
y_pred = lr.predict(X_test)
print("Confusion Matrix:\n", confusion_matrix(Y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[12107     0]
#  [    0  7893]]

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy: ",accuracy)
# Out:
# Accuracy:  1.0

# %%
prediction = lr.predict([[5, 1, 1.72, 2]])
print(prediction)
# Out:
# [1]
# C:\Users\Loki\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
prediction = lr.predict([[2, 0, 1.25, 1]])
print(prediction)
# Out:
# [0]
# C:\Users\Loki\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
